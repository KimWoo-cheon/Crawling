# %%
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pandas as pd
import time

# %%
driver = wb.Chrome()
driver.get('https://www.coupang.com/np/categories/194276?listSize=60&brand=&offerCondition=&filterType=&isPriceRange=false&minPrice=&maxPrice=&channel=user&fromComponent=N&selectedPlpKeepFilter=&sorter=saleCountDesc&filter=&rating=4')
time.sleep(1)
name=[]
# origin=[]
# cate=[]
menu_list=driver.find_elements(By.CLASS_NAME,'name') # 정 못찾겠으면 X태그
# # item1 = driver.find element(By.XPATH, f'//*[@id="qBestWrap"]/div[2]/ul/li[{i+1}]/div[1]

for i in menu_list:

    name.append(i.text)


data={ '제품명': name, '원가':origin, '카테고리':cate}
df=pd.DataFrame(data)
df
# Out:
#                                     제품명
# 0                      국내산 애호박, 1개입, 1개
# 1                          흙대파, 1kg, 1개
# 2                서울우유 1급A우유, 2300ml, 1개
# 3                      탐사수 무라벨, 2L, 12개
# 4      친환경 국내산 팽이버섯, 300g(150gx2개입), 1개
# 5                   곰곰 국내산 백오이, 5개입, 1개
# 6                   곰곰 국내산 흙당근, 1kg, 1개
# 7                  곰곰 국내산 양파, 1.5kg, 1개
# 8                    국내산 청양고추, 150g, 1개
# 9                  곰곰 아삭한 콩나물, 500g, 1봉
# 10                  국내산 감자(햇), 500g, 1개
# 11            델몬트 필리핀 바나나, 1.4kg 내외, 1개
# 12                       국내산 무, 1개입, 1개
# 13                     돌 바나나, 1.2kg, 1개
# 14                제주삼다수 그린 무라벨, 2L, 12개
# 15    맥심 모카골드 마일드 커피믹스, 12g, 160개입, 1박스
# 16                  탐사수 무라벨, 500ml, 40개
# 17               서울우유 후레쉬 밀크, 900ml, 2개
# 18                    곰곰 우유식빵, 330g, 1개
# 19       서울우유 더 진한 순수 플레인 요거트, 1.8L, 1개
# 20                  돌 스위티오 바나나, 1kg, 1개
# 21                   국내산 양파(소), 1kg, 1개
# 22                    국내산 깐마늘, 200g, 1개
# 23                     국내산 깐마늘, 80g, 1개
# 24                 곰곰 신선한 우유, 900ml, 1개
# 25                      곰곰 양상추, 1개입, 1개
# 26                    국내산 브로콜리, 1개입, 1개
# 27                곰곰 아삭한 숙주나물, 300g, 1봉
# 28                      완숙 토마토, 1kg, 1팩
# 29               곰곰 국내산 감자 (햇), 1kg, 1개
# 30                   곰곰 완숙 토마토, 1kg, 1개
# 31                  곰곰 국내산 알배기, 1개입, 1개
# 32                 곰곰 신선한 우유, 900ml, 2개
# 33                       탐사 샘물, 2L, 12개
# 34    서울우유 목장의 신선함이 살아있는 우유, 1000ml, 1개
# 35        삼립 56시간 저온숙성 탕종 숙식빵, 420g, 1개
# 36        신세계푸드 에콰도르 달콤 바나나, 1개, 1.25kg
# 37              풀무원 크고 단단한 두부, 500g, 1개
# 38                      농심 올리브 짜파게티, 5개
# 39                  곰곰 국내산 백오이, 3개입, 1개
# 40                     파프리카 혼합, 2개입, 1개
# 41                곰곰 아삭한 숙주나물, 500g, 1개
# 42                           농심 신라면, 5개
# 43                          농심 신라면, 10개
# 44                  친환경 새송이버섯, 400g, 1개
# 45    풀무원 특등급 국산콩 두부 부침찌개 겸용, 300g, 2개입
# 46        다향오리 1등급 훈제 오리 슬라이스, 600g, 1개
# 47        세도농협 GAP 인증 대추방울토마토, 1kg, 1박스
# 48            곰곰 무농약인증 국산 콩나물, 300g, 1개
# 49                      제주 삼다수, 2L, 12개
# 50                  조인 무항생제 대란, 30구, 1개
# 51        풀무원 특등급 국산콩 무농약 콩나물, 340g, 1개
# 52                풀무원 소가 찌개두부, 300g, 2개
# 53                 제주삼다수 그린, 500ml, 40개
# 54                풀무원 소가 찌개두부, 290g, 1개
# 55              국내산 무농약 느타리버섯, 200g, 1개
# 56  곰곰 소중한 우리쌀 2023년(햅쌀), 10kg(상등급), 1개
# 57                     곰곰 콩두부, 500g, 2개
# 58            남양유업 맛있는 우유 GT, 900ml, 1개
# 59                  탐사수 무라벨, 500ml, 60개

# %%
dfStyler = df.style.set_properties(**{'text-align': 'center'})
dfStyler.set_table_styles([dict(selector='th',props=[('text-align', 'center')])])
# Out:
# <style type="text/css">
# #T_e640e th {
#   text-align: center;
# }
# #T_e640e_row0_col0, #T_e640e_row1_col0, #T_e640e_row2_col0, #T_e640e_row3_col0, #T_e640e_row4_col0, #T_e640e_row5_col0, #T_e640e_row6_col0, #T_e640e_row7_col0, #T_e640e_row8_col0, #T_e640e_row9_col0, #T_e640e_row10_col0, #T_e640e_row11_col0, #T_e640e_row12_col0, #T_e640e_row13_col0, #T_e640e_row14_col0, #T_e640e_row15_col0, #T_e640e_row16_col0, #T_e640e_row17_col0, #T_e640e_row18_col0, #T_e640e_row19_col0, #T_e640e_row20_col0, #T_e640e_row21_col0, #T_e640e_row22_col0, #T_e640e_row23_col0, #T_e640e_row24_col0, #T_e640e_row25_col0, #T_e640e_row26_col0, #T_e640e_row27_col0, #T_e640e_row28_col0, #T_e640e_row29_col0, #T_e640e_row30_col0, #T_e640e_row31_col0, #T_e640e_row32_col0, #T_e640e_row33_col0, #T_e640e_row34_col0, #T_e640e_row35_col0, #T_e640e_row36_col0, #T_e640e_row37_col0, #T_e640e_row38_col0, #T_e640e_row39_col0, #T_e640e_row40_col0, #T_e640e_row41_col0, #T_e640e_row42_col0, #T_e640e_row43_col0, #T_e640e_row44_col0, #T_e640e_row45_col0, #T_e640e_row46_col0, #T_e640e_row47_col0, #T_e640e_row48_col0, #T_e640e_row49_col0, #T_e640e_row50_col0, #T_e640e_row51_col0, #T_e640e_row52_col0, #T_e640e_row53_col0, #T_e640e_row54_col0, #T_e640e_row55_col0, #T_e640e_row56_col0, #T_e640e_row57_col0, #T_e640e_row58_col0, #T_e640e_row59_col0 {
#   text-align: center;
# }
# </style>
# <table id="T_e640e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e640e_level0_col0" class="col_heading level0 col0" >제품명</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e640e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e640e_row0_col0" class="data row0 col0" >국내산 애호박, 1개입, 1개</td>
#     </tr>
#     <tr>
#       <th id="T_e640e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e640e_row1_col0" class="data row1 col0" >흙대파, 1kg, 1개</td>
#     </tr>
#     <tr>
#       <th id="T_e640e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e640e_row2_col0" class="data row2 col0" >서울우유 1급A우유, 2300ml, 1개</td>
#     </tr>
#     <tr>
#       <th id="T_e640e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e640e_row3_col0" class="data row3 col0" >탐사수 무라벨, 2L, 12개</td>
#     </tr>
#     <tr>
#       <th id="T_e640e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e640e_row4_col0" class="data row4 col0" >친환경 국내산 팽이버섯, 300g(150gx2개입), 1개</td>
#     </tr>
#     <tr>
#       <th id="T_e640e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e640e_row5_col0" class="data row5 col0" >곰곰 국내산 백오이, 5개입, 1개</td>
#     </tr>
#     <tr>
#       <th id="T_e640e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e640e_row6_col0" class="data row6 col0" >곰곰 국내산 흙당근, 1kg, 1개</td>
#     </tr>
#     <tr>
#       <th id="T_e640e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e640e_row7_col0" class="data row7 col0" >곰곰 국내산 양파, 1.5kg, 1개</td>
#     </tr>
#     <tr>
#       <th id="T_e640e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e640e_row8_col0" class="data row8 col0" >국내산 청양고추, 150g, 1개</td>
#     </tr>
#     <tr>
#       <th id="T_e640e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e640e_row9_col0" class="data row9 col0" >곰곰 아삭한 콩나물, 500g, 1봉</td>
#     </tr>
#     <tr>
#       <th id="T_e640e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e640e_row10_col0" class="data row10 col0" >국내산 감자(햇), 500g, 1개</td>
#     </tr>
#     <tr>
#       <th id="T_e640e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e640e_row11_col0" class="data row11 col0" >델몬트 필리핀 바나나, 1.4kg 내외, 1개</td>
#     </tr>
#     <tr>
#       <th id="T_e640e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e640e_row12_col0" class="data row12 col0" >국내산 무, 1개입, 1개</td>
#     </tr>
#     <tr>
#       <th id="T_e640e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e640e_row13_col0" class="data row13 col0" >돌 바나나, 1.2kg, 1개</td>
#     </tr>
#     <tr>
#       <th id="T_e640e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e640e_row14_col0" class="data row14 col0" >제주삼다수 그린 무라벨, 2L, 12개</td>
#     </tr>
#     <tr>
#       <th id="T_e640e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e640e_row15_col0" class="data row15 col0" >맥심 모카골드 마일드 커피믹스, 12g, 160개입, 1박스</td>
#     </tr>
#     <tr>
#       <th id="T_e640e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e640e_row16_col0" class="data row16 col0" >탐사수 무라벨, 500ml, 40개</td>
#     </tr>
#     <tr>
#       <th id="T_e640e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e640e_row17_col0" class="data row17 col0" >서울우유 후레쉬 밀크, 900ml, 2개</td>
#     </tr>
#     <tr>
#       <th id="T_e640e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_e640e_row18_col0" class="data row18 col0" >곰곰 우유식빵, 330g, 1개</td>
#     </tr>
#     <tr>
#       <th id="T_e640e_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_e640e_row19_col0" class="data row19 col0" >서울우유 더 진한 순수 플레인 요거트, 1.8L, 1개</td>
#     </tr>
#     <tr>
#       <th id="T_e640e_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_e640e_row20_col0" class="data row20 col0" >돌 스위티오 바나나, 1kg, 1개</td>
#     </tr>
#     <tr>
#       <th id="T_e640e_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_e640e_row21_col0" class="data row21 col0" >국내산 양파(소), 1kg, 1개</td>
#     </tr>
#     <tr>
#       <th id="T_e640e_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_e640e_row22_col0" class="data row22 col0" >국내산 깐마늘, 200g, 1개</td>
#     </tr>
#     <tr>
#       <th id="T_e640e_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_e640e_row23_col0" class="data row23 col0" >국내산 깐마늘, 80g, 1개</td>
#     </tr>
#     <tr>
#       <th id="T_e640e_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_e640e_row24_col0" class="data row24 col0" >곰곰 신선한 우유, 900ml, 1개</td>
#     </tr>
#     <tr>
#       <th id="T_e640e_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_e640e_row25_col0" class="data row25 col0" >곰곰 양상추, 1개입, 1개</td>
#     </tr>
#     <tr>
#       <th id="T_e640e_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_e640e_row26_col0" class="data row26 col0" >국내산 브로콜리, 1개입, 1개</td>
#     </tr>
#     <tr>
#       <th id="T_e640e_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_e640e_row27_col0" class="data row27 col0" >곰곰 아삭한 숙주나물, 300g, 1봉</td>
#     </tr>
#     <tr>
#       <th id="T_e640e_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_e640e_row28_col0" class="data row28 col0" >완숙 토마토, 1kg, 1팩</td>
#     </tr>
#     <tr>
#       <th id="T_e640e_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_e640e_row29_col0" class="data row29 col0" >곰곰 국내산 감자 (햇), 1kg, 1개</td>
#     </tr>
#     <tr>
#       <th id="T_e640e_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_e640e_row30_col0" class="data row30 col0" >곰곰 완숙 토마토, 1kg, 1개</td>
#     </tr>
#     <tr>
#       <th id="T_e640e_level0_row31" class="row_heading level0 row31" >31</th>
#       <td id="T_e640e_row31_col0" class="data row31 col0" >곰곰 국내산 알배기, 1개입, 1개</td>
#     </tr>
#     <tr>
#       <th id="T_e640e_level0_row32" class="row_heading level0 row32" >32</th>
#       <td id="T_e640e_row32_col0" class="data row32 col0" >곰곰 신선한 우유, 900ml, 2개</td>
#     </tr>
#     <tr>
#       <th id="T_e640e_level0_row33" class="row_heading level0 row33" >33</th>
#       <td id="T_e640e_row33_col0" class="data row33 col0" >탐사 샘물, 2L, 12개</td>
#     </tr>
#     <tr>
#       <th id="T_e640e_level0_row34" class="row_heading level0 row34" >34</th>
#       <td id="T_e640e_row34_col0" class="data row34 col0" >서울우유 목장의 신선함이 살아있는 우유, 1000ml, 1개</td>
#     </tr>
#     <tr>
#       <th id="T_e640e_level0_row35" class="row_heading level0 row35" >35</th>
#       <td id="T_e640e_row35_col0" class="data row35 col0" >삼립

# %%
# csv 파일로 내보내기
df.to_csv('G마켓.csv', encoding ='euc-kr')

# %% [markdown]
# #### GMarket 그룹별 데이터 수집 및 저장
# 1. 'All'을 제외한 나머지 그룹메뉴를 클릭하여 순차적으로 넘어간다
#     - 첫번째 방법 : 그룹별 메뉴를 하나씩 클릭하여 넘어가기
#     - 두번째 방법 : 그룹별 URL패턴을 분석하여 페이지 넘어가기
# 3. 각 그룹에 해당하는 상품 데이터 (상품명, 가격)을 수집한다.
# 4. 모든 그룹에 대한 데이터 수집 완료시, CSV파일로 저장한다.

# %%
driver = wb.Chrome()
driver.get('https://www.gmarket.co.kr/n/best')
time.sleep(1)

# %%
driver.get('https://www.gmarket.co.kr/n/best')
name_list=[]
price_list=[]

# group_list

# %%
i=11
driver.find_element(By.CLASS_NAME,f'group{i+1}').click()

# %%
driver = wb.Chrome()
driver.get('https://www.gmarket.co.kr/n/best')
time.sleep(1)
driver.get('https://www.gmarket.co.kr/n/best')
name_list=[]
price_list=[]
group_list=[]
grouping=driver.find_elements(By.CSS_SELECTOR,'li.groupA.on~li')
# for j in grouping :
num=1
num_list=[]
for i in range(12):
    for j in range(100) :
       group_list.append(grouping[i].text)



for i in range(12) :
    driver.find_element(By.CLASS_NAME,f'group{i+1}').click()
    time.sleep(0.5)
    for n in range(100) :
        name_list.append(driver.find_element(By.CSS_SELECTOR,f'.no{n+1}~.itemname').text)
        price_list.append(driver.find_element(By.CSS_SELECTOR,f'.no{n+1}~.item_price>.s-price > strong>span').text)
        num_list.append(num)
        num=num+1
print(len(name_list))
print(len(price_list))
print(len(group_list)) 
print(len(num_list))
# Out:
# 1200
# 1200
# 1200
# 1200

# %%
data2={'분류' : group_list, '제품명': name_list, '가격':price_list, }
df2=pd.DataFrame(data2)
df2
# Out:
#         분류                                                제품명       가격
# 0     패션의류  ((10%+10%쿠폰)) 시크릿무드 초특가SALE 썸머 신상 BEST/청바지/슬랙스...   9,900원
# 1     패션의류       15+15%빅스마일 라이브기념 추가할인 게스본사 SS특가 티셔츠/데님/모자 행사  28,000원
# 2     패션의류                [폴햄]20+7%쿠폰|본사직영 폴햄 빅세일 셔츠/티셔츠/팬츠 외  13,900원
# 3     패션의류  (10%+10%쿠폰/역마진SALE) 4960원~ 여름신상/쿨팬츠/데님/카고/조거/트...   8,700원
# 4     패션의류  [저스트원](10%쿠폰) 베스트 모음 신상/셔츠/슬랙스/청바지/일자/긴팔/반팔/조끼/니트  17,990원
# ...    ...                                                ...      ...
# 1195   e쿠폰                     [투썸플레이스](투썸플레이스) 스트로베리 초콜릿 생크림  35,890원
# 1196   e쿠폰                         [해피머니상품권](해피머니) 온라인상품권 3만원  28,650원
# 1197   e쿠폰                          [에그머니](에그머니) 온라인게임상품권 3만원  27,450원
# 1198   e쿠폰                    [올리브영](올리브영) 기프트카드 5만원권(즉시사용가능)  50,000원
# 1199   e쿠폰                            [뚜레쥬르](뚜레쥬르) 곰돌이 푸_알럽허니  24,000원
#
# [1200 rows x 3 columns]

# %%
bins=[0,100,200,300,400,500,600,700,800,900,1000,1100,1200]
labels=grouping
pie=pd.cut(num_list, bins, labels=labels)

# %%
title_list = []
price_list = []
group_list = []

for i in range(len(href_list)):
    driver.get(href_list[i])

    time.sleep(1)

    titles = driver.find_elements(By.CLASS_NAME, 'itemname')
    prices = driver.find_elements(By.CSS_SELECTOR, 'div.s-price > strong > span')
    groups = driver.find_elements(By.CSS_SELECTOR , '#categoryTabG > li.groupA ~ li > a')
    
    for j in range(len(titles)):
        title_list.append(titles[j].text)
        price_list.append(prices[j].text)
        group_list.append(groups[i].text)
    
len(title_list), len(price_list), len(group_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 5
#       2 price_list = []
#       3 group_list = []
# ----> 5 for i in range(len(href_list)):
#       6     driver.get(href_list[i])
#       8     time.sleep(1)
#
# NameError: name 'href_list' is not defined
